# %%
# import libraries
import os
import asyncio
import logging
from typing import List, Dict, Any
from dotenv import load_dotenv

# %%
# essential core patches for vs code notebook runtime kernels

import nest_asyncio
nest_asyncio.apply()

# %%
# configure high-visibility logs directly in the notebook output

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[logging.StreamHandler()]
)
logger = logging.getLogger("AdvancedAgenticEngine")
